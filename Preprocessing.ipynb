# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
import pandas as pd

# %%
data = pd.read_csv('kc_house_data.csv')
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
data[data['date']=='10/13/2014']
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 76     4036801170  10/13/2014   380000.0         4       1.75         1760
# 542    1310900260  10/13/2014   318888.0         4       1.75         2320
# 551    1373800295  10/13/2014  1450000.0         3       3.00         4380
# 684    5102400105  10/13/2014   400000.0         4       1.00         1420
# ...           ...         ...        ...       ...        ...          ...
# 19965  1489300215  10/13/2014  1210000.0         4       3.25         3330
# 20919  6382500084  10/13/2014   577450.0         3       3.00         1730
# 21064  2690100170  10/13/2014   300000.0         3       2.50         1960
# 21229  3682000050  10/13/2014   349950.0         4       2.50         2632
# 21582  8956200760  10/13/2014   541800.0         4       2.50         3118
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data['condition'].value_counts()
# Out:
# 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: condition, dtype: int64
